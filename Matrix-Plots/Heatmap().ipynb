# %% [markdown]
# Requires the data to be in a grid format

# %%
sns.heatmap(pd.crosstab(df['column1'], df['column2'], 
                       values=df['totals_column'], aggfunc='mean'))

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Customizing a heatmap

# %%
sns.heatmap(df, annot=True, fmt='d',
           cmap='YlGnBu', cbar=False, linewidths=0.5)

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### plotting the Correlation Matrix

# %%
sns.heatmap(df.corr())

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)
