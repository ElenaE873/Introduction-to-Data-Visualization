# %% [markdown]
# ### stripplot

# %%
sns.stripplot(data=df,
             y="YLabel",
             x="XLabel",
             jitter=True)

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### swarmplot

# %%
sns.swarmplot(data=df,
              y="YLabel",
              x="XLabel")

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### boxplot

# %%
sns.boxplot(data=df,
              y="YLabel",
              x="XLabel")

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### violinplot

# %%
sns.violinplot(data=df,
              y="YLabel",
              x="XLabel")

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### lvplot (letter value)

# %%
sns.lvplot(data=df,
              y="YLabel",
              x="XLabel")

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### barplot (ie. a statistical plot)

# %%
sns.barplot(data=df,
              y="YLabel",
              x="XLabel",
           hue='column')

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### pointplot

# %%
#similar to barplot
sns.pointplot(data=df,
              y="YLabel",
              x="XLabel",
           hue='column')

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### countplot

# %%
sns.countplot(data=df,
              y="YLabel",
              x="XLabel",
           hue='column')

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### regplot() with categorical data

# %%
sns.regplot(data=df, x='column1', y='column2',
           x_jitter=.1,
           order=2)

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### using an estimator of the data

# %%
sns.regplot(data=df, x='column1', y='column2',
            x_estimator=np.mean,
           order=2)

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Binning the data

# %% [markdown]
# - can be used to divide the data and see the regression line fit to the bins

# %%
sns.regplot(data=df, x='column1', y='column2', x_bins=4)

# %% [markdown]
# Example

# %% [markdown]
# ![image.png](attachment:image.png)
