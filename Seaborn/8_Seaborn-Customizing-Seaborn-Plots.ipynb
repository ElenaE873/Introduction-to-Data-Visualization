# %% [markdown]
# ##### why consider customizations?

# %% [markdown]
# - improve readability
# - orient the audience more quickly to the key takeaway
# - guide interpretation

# %% [markdown]
# ##### "style" background/axes

# %% [markdown]
# - "White"
# - "dark"
# - "Whitegrid"
# - "darkgrid"
# - "ticks

# %%
#using the following 
sns.set_style()

# %% [markdown]
# ##### color palletes

# %%
#using the following
sns.set_palette()

# %% [markdown]
# Seaborn Diverging Palettes
# ![image.png](attachment:image.png)

# %% [markdown]
# Useful when:
# - Trying to differentiate between shifts in data from small quantities to large quantities possibly.

# %% [markdown]
# Sequential Palettes
# ![image.png](attachment:image.png)

# %% [markdown]
# Useful when:
# - Exploring a continous variable

# %% [markdown]
# ##### customizing palettes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
