# %% [markdown]
# Seaborn plots create two different types of objects:
# - FaceGrid
# - AxesSubplot

# %%
#how to find out which type of object you're working with?

# - 1 assign plot to a variable

plot = sns.scatterplot(x="column1",
                      y="column2",
                      data=df)
type(plot)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Setting the title to FacetGrid

# %%
plot.fig.suptitle("Title Name") #yes, it's "sup"
#title for figure as a whole

plot.fig.suptitle("Title Name",
                 y=1.03)  #labeling with title higher

# %% [markdown]
# ##### Setting the title to AxesSubplot

# %%
plot.set_title("TitleName")

#or
plot.set_title("Title by {col_name}")

# %% [markdown]
# ##### Setting the Axis Lables

# %%
plot.set(xlabel="X axis Description",
        ylabel="Y axis Description")

# %% [markdown]
# ##### Rotate Ticks 90 Degrees

# %%
plt.xticks(rotation=90)
